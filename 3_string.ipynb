# %%
## what is string?
a="symbios"
print(a, type(a))
# Out:
# symbios <class 'str'>

# %%
b= 'new values are '
b
# Out:
# 'new values are '

# %%
para = """Hi , Hello!
    I'm there with you"""

# %%
print(para)
# Out:
# Hi , Hello!
#     I'm there with you

# %%
## concatenation of the string
name = "Nutan"

print(para + name)
# Out:
# Hi , Hello!
#     I'm there with youNutan

# %%
para.isalpha()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
number = '1234567'

# %%
number.isdigit()
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## .format()
"{}, {}".format(name,number)
# Out:
# 'Nutan, 1234567'

# %%
"{1},{0}".format(name, number)
# Out:
# '1234567,Nutan'

# %%
## "{:25},{:10.2f}".format(a ,b )
number = 1234.2345

print("{:3}  , {:10.2f} ".format(name, number))
# Out:
# Nutan  ,    1234.23

# %%
### Alignment  ^ >

print("{:^10}, {:>10}".format(name, number))
# Out:
#   Nutan   ,    1234567

# %%
### Display sign of the number
a,b = +123, -4567

print("{:+10},{:+10}".format(a,b))
# Out:
#       +123,     -4567

# %%
print("{:-10},{:-10}".format(a,b))
# Out:
#        123,     -4567
