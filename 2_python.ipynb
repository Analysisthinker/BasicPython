# %%
## Values and Data Types

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Variables, Keywords, 
a, b = 20,30
a,b
# Out:
# (20, 30)

# %%
a_123= 203

# %%
234q=20
# Out:
#   File "<ipython-input-8-a3582b86d57e>", line 1
#     234q=20
#        ^
# SyntaxError: invalid syntax

# %%
aq@

# %%
## # comment
### print(a,b)
"""  name = amrita"""
# Out:
# '  name = amrita'

# %%
### String Literals, Escape Sequences

'don\'t'
# Out:
# "don't"

# %%
### Operators and Operands,

# %%
### explain indentation
if a < 40:
print('a is less than 40')
# Out:
#   File "<ipython-input-15-a383bc06a960>", line 3
#     print('a is less than 40')
#     ^
# IndentationError: expected an indented block

# %%
## arithmatic operator
11%2
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## logical operator
a<40 and b>20
# Out:
# True

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
## comparative operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## expression

(a+b)**2
# Out:
# 2500

# %%
## statments
a>30 or b<100 and
# Out:
# 1
