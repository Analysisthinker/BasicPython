# %%
import os
os.listdir('D:\\new_files')
# Out:
# ['100.txt', '30.txt', '70.txt']

# %%
path1= r'D:\Symbiosis_recording-20230603T131603Z-001\Symbiosis_recording\completed\shared'
path1
# Out:
# 'D:\\Symbiosis_recording-20230603T131603Z-001\\Symbiosis_recording\\completed\\shared'

# %%
import os
def fn(path):       # 1.Get file names from directory
    file_list=os.listdir(path)
    for i in file_list:
        file_name = path+'\\'+i
        d=os.stat(file_name).st_size
        print (i,d)

 #2.To rename files

# %%
fn(path1)
# Out:
# .ipynb_checkpoints 0
# 10_functions.pptx 307731
# 11_lambda_function.pptx 390923
# 12_Exception.pptx 457228
# 13_reading_writing_files.pptx 117799
# 14_file_transfer.pptx 281484
# 1_Introduction to Python Programming.pptx 2669205
# 2_Variables, Expressions and Statements.pptx 218222
# 3_String opertation.pptx 374209
# 4_list.pptx 172358
# 5_tuple_set.pptx 327138
# 6_dictionary.pptx 201563
# 7_conditional_statement.pptx 283664
# 8_loops.pptx 318405
# 9_itertools.pptx 435253

# %%
import shutil
shutil.copy('myfile.txt', 'D:\\Symbiosis_recording-20230603T131603Z-001\\Symbiosis_recording\\completed\\shared\\target.txt')
# Out:
# 'D:\\Symbiosis_recording-20230603T131603Z-001\\Symbiosis_recording\\completed\\shared\\target.txt'

# %%
shutil.move('myfile.txt', 'D:\\Printable_doc\\moved.txt')
# Out:
# 'D:\\Printable_doc\\moved.txt'

# %%
shutil.copytree('D:\\Printable_doc','D:\\Printable_doc\\R\\Print_folder')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-c15761c73a67> in <module>
# ----> 1 shutil.copytree('D:\\Printable_doc','D:\\Printable_doc\\R\\Print_folder')
#
# ~\anaconda3\lib\shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     552     with os.scandir(src) as itr:
#     553         entries = list(itr)
# --> 554     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     555                      ignore=ignore, copy_function=copy_function,
#     556                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# ~\anaconda3\lib\shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     508             errors.append((src, dst, str(why)))
#     509     if errors:
# --> 510         raise Error(errors)
# ...
